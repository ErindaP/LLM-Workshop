# %% [markdown]
# <a href="https://colab.research.google.com/github/ErindaP/LLM-Workshop/blob/main/ChessMistral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# base model from huggingFace or path to model
base_model = "mistralai/Mistral-7B-Instruct-v0.2"
new_model = "ChessMistralGGUF"

test_path='/content/DataTest.csv'
train_path='/content/DataTraining.csv'

# %%
# %%capture
#!git clone 'https://github.com/ali7919/Enlighten-Instruct.git'
# !pip install -U bitsandbytes
# !pip install transformers==4.36.2
# !pip install -U peft
# !pip install -U accelerate
# !pip install -U trl
# !pip install datasets==2.16.0
# !pip install sentencepiece

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig,HfArgumentParser,TrainingArguments,pipeline, logging
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training, get_peft_model
import os,torch
from datasets import load_dataset
from trl import SFTTrainer
import pandas as pd
import pyarrow as pa
import pyarrow.dataset as ds
import pandas as pd
from datasets import Dataset
import re
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %% [markdown]
# # Login to HF

# %%
from google.colab import userdata
secret_hf = userdata.get('HUGGINGFACE_TOKEN')
# !huggingface-cli login --token $secret_hf
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
secret_hf_read = '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'
secret_hf_write = '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'

# !huggingface-cli login --token $secret_hf_read
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Build Dataset

# %%
df = pd.read_csv(train_path)

# build training dataset with the right format
df['text'] = '<s>[INST]@Opening. ' + df['Q'] +'[/INST]'+ df['A'] + '</s>'

# remove columns
df=df.drop(['Q','A','opening'],axis=1)

# convert to dataset object
dataset = ds.dataset(pa.Table.from_pandas(df).to_batches())
dataset = Dataset(pa.Table.from_pandas(df))
dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 160
# })

# %% [markdown]
# # Load the model

# %%
# Load base model
bnb_config = BitsAndBytesConfig(
    load_in_4bit= True,
    bnb_4bit_quant_type= "nf4",
    bnb_4bit_compute_dtype= torch.bfloat16,
    bnb_4bit_use_double_quant= False,
)
model = AutoModelForCausalLM.from_pretrained(
        base_model,
        load_in_4bit=True,
        quantization_config=bnb_config,
        torch_dtype=torch.bfloat16,
        device_map="auto",
        trust_remote_code=True,
)


model.config.use_cache = False # silence the warnings. Please re-enable for inference!
model.config.pretraining_tp = 1
model.gradient_checkpointing_enable()

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)
tokenizer.padding_side = 'right'
tokenizer.pad_token = tokenizer.eos_token
tokenizer.add_eos_token = True
tokenizer.bos_token, tokenizer.eos_token
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# ('<s>', '</s>')

# %%
# count trainging tokens
from transformers import LlamaTokenizer
tokenizer_ = LlamaTokenizer.from_pretrained("cognitivecomputations/dolphin-llama2-7b")
tokens = tokenizer_.tokenize(dataset.to_pandas().to_string())
len(tokens)
# Out:
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# 12240

# %% [markdown]
# # Fine-Tune

# %%
#Adding the adapters in the layers
model = prepare_model_for_kbit_training(model)
peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj","gate_proj"]
)
model = get_peft_model(model, peft_config)

# %%
#Hyperparamter
training_arguments = TrainingArguments(
    output_dir="./results",
    num_train_epochs=1,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=50,
    logging_steps=1,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=False,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
)

# %%
# Setting sft parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    max_seq_length= None,
    dataset_text_field="text",
    tokenizer=tokenizer,
    args=training_arguments,
    packing= False,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:246: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:446: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False)
#   warnings.warn(

# %%
trainer.train()
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='40' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [40/40 02:53, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.966800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.730800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.153400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.929500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.530100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.385400</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.781000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.547400</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.322600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.116200</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.020200</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.866700</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.847700</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.983000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.744400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.333400</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.501200</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.516400</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.220600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.599300</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.778600</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.591000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.977200</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.742800</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.656900</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.817100</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.770400</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.728100</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.781600</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.901600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.057600</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.724800</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.785500</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.584000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.850900</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.870100</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.795900</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.571500</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.658200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.810000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=40, training_loss=1.2887498199939729, metrics={'train_runtime': 181.7972, 'train_samples_per_second': 0.88, 'train_steps_per_second': 0.22, 'total_flos': 448944519217152.0, 'train_loss': 1.2887498199939729, 'epoch': 1.0})

# %% [markdown]
# # Save and push the adapter to HF

# %%
# Save the fine-tuned model
model.save_pretrained(new_model)
trainer.model.save_pretrained(new_model)
tokenizer.save_pretrained(new_model)
model.config.use_cache = True
model.eval()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32000, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (rotary_emb): MistralRotaryEmbedding()
#             )
#             (mlp): MistralMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm()
#             (post_attention_layernorm): MistralRMSNorm()
#           )
#         )
#         (norm): MistralRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )

# %%
trainer.model.push_to_hub(new_model)
# Out:
# adapter_model.safetensors:   0%|          | 0.00/369M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/codersan/Enlighten_Instruct/commit/fed7033bf5cf8095e5075686926756affd82b21b', commit_message='Upload model', commit_description='', oid='fed7033bf5cf8095e5075686926756affd82b21b', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # Test the model

# %%
logging.set_verbosity(logging.CRITICAL)
pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)

# %%
def build_prompt(question):
  prompt=f"<s>[INST]@Opening. {question} [/INST]"
  return prompt

# %%
question = "why is the grunfeld opening risky?"
prompt = build_prompt(question)
result = pipe(prompt)

print(result[0]['generated_text'])
# Out:
# <s>[INST]@Opening. why is the grunfeld opening risky? [/INST]\"Black can often gain the initiative by controlling the \"f4\" square and attacking the \"e4\" pawn.\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"\"

# %%
df_test=pd.read_csv(test_path)

questionCounter=0
correct=0
promptEnding = "[/INST]"

# this must be >= 2
fail_limit=10

# chain of thought activator, model might run out of output tokens
USE_COT=True

#this comes before the question
testGuide='Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d \n'

for index, row in df_test.iterrows():
    print("#############################")
    questionCounter = questionCounter + 1

    #chain of thought activator
    if USE_COT:
        chainOfThoughtActivator='\nfirst think step by step\n'
    else:
        chainOfThoughtActivator='\n'

    #build the prompt
    question=testGuide + row['Question'] + '\na)' + row['a'] + '\nb)' + row['b'] + '\nc)' + row['c'] + '\nd)' + row['d'] + chainOfThoughtActivator
    print(question)

    #true answer
    truth=row['Answer']

    #use a loop, if llm stopped before reaching the answer. ask again
    index=-1
    failCounter=0
    while(index==-1):

        #build the prompt
        prompt = build_prompt(question)

        #generate answer
        result = pipe(prompt)
        llmAnswer = result[0]['generated_text']

        #remove our prompt from it
        index = llmAnswer.find(promptEnding)
        llmAnswer = llmAnswer[len(promptEnding)+index:]

        print("LLM Answer:")
        print(llmAnswer)

        #remove spaces
        llmAnswer=llmAnswer.replace(' ','')

        #find the option in response
        index = llmAnswer.find('Answer:')

        #edge case - llm stoped at the worst time
        if(index+len('Answer:')==len(llmAnswer)):
            index=-1

        #update question for the next try. remove chain of thought
        question=testGuide + row['Question'] + '\na)' + row['a'] + '\nb)' + row['b'] + '\nc)' + row['c'] + '\nd)' + row['d']

        #Don't get stock on a question
        failCounter=failCounter+1
        if failCounter==fail_limit:
            break

    if failCounter==fail_limit:
        continue

    #find and match the option
    next_char = llmAnswer[index+len('Answer:'):][0]
    if next_char in truth:
        correct=correct+1
        print('correct')
    else:
        print('wrong')

    #update accuracy
    accuracy=correct/questionCounter
    print(f"Progress: {questionCounter/len(df_test)}")
    print(f"Accuracy: {accuracy}")
# Out:
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main move that characterizes the Ruy Lopez opening?
# a)The main move of the Ruy Lopez opening is :
#  3. Bb5  ..
# b)The main move of the Ruy Lopez opening is :
#  3. Nc3  ..
# c)The main idea of the Ruy Lopez  is :
#  1. e4  ..
# d)The threat of the Ruy Lopez opening is a strong control of the center.
# first think step by step
#
# LLM Answer:
# The main move that characterizes the Ruy Lopez opening is : 3. Bb5.
#
# Answer: a.
#
# Explan
# correct
# Progress: 0.03333333333333333
# Accuracy: 1.0
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the first move of the black pieces in the Caro-Khan opening ?
# a)The first black move of the Caro-Khan is :
#  1... Nc6
# b)The first move of the Caro-Khan opening is :
#  1. e4 c6
# c)The idea of the Caro-Khan opening is to make the bishop in b7
# d)The first move of the Caro-Khan is :
#  1. e4 d6
# first think step by step
#
# LLM Answer:
# The first move of the Caro-Khan opening is made by Black, and it is \"1... Nf6.\" However, the question asks for the
# LLM Answer:
# Answer: a
#
# Explanation:
# In the Caro-Khan opening, the first move of the black pieces is \"1... Nc6.\" This move allows Black to
# correct
# Progress: 0.06666666666666667
# Accuracy: 1.0
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the third move often played by white in the Queen's Gambit?
# a)The third move often played by white in the Queen's Gambit is :
#  3. Nd2  ..
# b)The third move often played by white in the Queen's Gambit is :
#  3. Bc4  ..
# c)The Queen's Gambit is characterized by the moves :
#  1. d4 d5  ..
# d)The purpose of the third move for white is often to develop the knight to a more central square.
# first think step by step
#
# LLM Answer:
# \"White plays the third move to develop the \"N\" knight to a more central
# LLM Answer:
# Answer: a. The third move often played by white in the Queen's Gambit is : 3.
# correct
# Progress: 0.1
# Accuracy: 1.0
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main idea of the Sicilian defense?
# a)The main idea of the Sicilian defense is :
#  to control the center with d7-d5
# b)The main idea of the Sicilian defense is :
#  to control the center with e7-e5
# c)The main line of the Sicilian  is :
#  1. e4 c5 ..
# d)The characteristic move of the Sicilian defense is :
#  e7-e5 ..
# first think step by step
#
# LLM Answer:
# The main idea of the Sicilian defense is :
# b) to control the center with e7-e5
#
# Explanation:
# The Sicilian defense
# LLM Answer:
# Answer: b. The main idea of the Sicilian defense is to control the center with e7-e5.
#
# Explanation:
# The Sicilian defense is a \"Black response to
# wrong
# Progress: 0.13333333333333333
# Accuracy: 0.75
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which square is typically attacked by the knight move in the French defense ?
# a)The square attacked by the knight move in the French defense is :
#  e4
# b)The square attacked by the knight move in the French defense is :
#  f3
# c)The French defense is characterized by the move :
#  1. e4 e6
# d)The threat of the French defense is to pin the knight on f3.
# first think step by step
#
# LLM Answer:
# The French defense is characterized by the move : 1. e4 e6.\"
#
# The French defense does not typically attack the square f3 with the knight move. Instead, it aims to control the center with pawns and
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# LLM Answer:
# Answer: b
#
# Explanation: In the French defense, the knight move attacks the square f3. This is because the \"French defense aims to control the center with pawns and pieces, while the knight on f3 can put pressure on the
# correct
# Progress: 0.16666666666666666
# Accuracy: 0.8
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main characteristic move of the King's Indian defense?
# a)The main characteristic move of the King's Indian defense is :
#  ...Nf6
# b)The main characteristic move of the King's Indian defense is :
#  c7-c5
# c)The characteristic move in the King's Indian typically excludes the move :
#  ...e7-e6
# d)The purpose of the King's Indian defense is often to put pressure on the center.
# first think step by step
#
# LLM Answer:
# The main characteristic move of the King's Indian defense is \"the move...Nf6.\" This move allows Black to control the \"f5\" square and put pressure on White's \"
# LLM Answer:
# Answer: a. The main characteristic move of the King's Indian defense is \"Nf6.\"
#
# Explanation: The King's Indian Defense is a popular opening for Black, characterized by an early move...
# correct
# Progress: 0.2
# Accuracy: 0.8333333333333334
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is Alekhine's Defense often considered ?
# a)Alekhine's Defense is often considered :
#  a hypermodern opening..
# b)Alekhine's Defense is often considered :
#  a classical opening..
# c)The main idea of Alekhine's Defense is to fianchetto the dark bishop to g7
# d)The first move of Alekhine's Defense is :
#  1. e4 Nf6
# first think step by step
#
# LLM Answer:
# The main idea of Alekhine's Defense is to fianchetto the dark bishop to g7. Therefore, the answer is:
#
# Answer: c
#
# Now, let's
# wrong
# Progress: 0.23333333333333334
# Accuracy: 0.7142857142857143
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main idea behind the Pirc Defense?
# a)The main idea behind the Pirc Defense is :
#  to slow down white's development and blockade the center.
# b)The main idea behind the Pirc Defense is :
#  to control the center with e7-e5
# c)The main line of the Pirc Defense is :
#  1. e4 d6 ..
# d)The Pirc Defense is considered a :
#  hypermodern opening.
# first think step by step
#
# LLM Answer:
# The main idea behind the Pirc Defense is :
# to slow down white's development and blockade the center.
#
# Answer: a
#
# Explanation:
# The Pirc Defense
# correct
# Progress: 0.26666666666666666
# Accuracy: 0.75
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the Scandinavian Defense considered ?
# a)The Scandinavian Defense is considered :
#  a flank opening..
# b)The Scandinavian Defense is considered :
#  a classical opening..
# c)The main line of the Scandinavian Defense is :
#  1.e4 d5 ..
# d)The threat of the Scandinavian Defense is to attack the center pawns with the queen..
# first think step by step
#
# LLM Answer:
# The Scandinavian Defense is considered a flank opening.
#
# Explanation:
# The Scandinavian Defense is characterized by \"Black playing...d5 and...c6, with the aim of
# LLM Answer:
# Answer: a. The Scandinavian Defense is considered a flank opening.
#
# Explanation: The Scandinavian Defense is characterized by \"Black playing...d5,...c6, and...e6, with the
# correct
# Progress: 0.3
# Accuracy: 0.7777777777777778
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main characteristic of the English Opening?
# a)The main characteristic of the English Opening is :
#  to fianchetto the kingside bishop to g2
# b)The main characteristic of the English Opening is :
#  to fianchetto  the queenside  to b2
# c)The main line of the English Opening is :
#  1. c4 ..
# d)The English Opening is considered a :
#  hypermodern opening.
# first think step by step
#
# LLM Answer:
# The main characteristic of the English Opening is :
# to fianchetto the kingside bishop to g2.
#
# Answer: a.
#
# Explanation:
#
# correct
# Progress: 0.3333333333333333
# Accuracy: 0.8
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the main move characterizing the Ruy Lopez opening?
# a)The purpose of the main move of the Ruy Lopez opening is :
#  to control the center with the bishop.
# b)The purpose of the main move of the Ruy Lopez opening is :
#  to develop the pawn on e2.
# c)The main idea of the Ruy Lopez  is :
#  1. e4  ..
# d)The threat of the Ruy Lopez opening is a strong development.
# first think step by step
#
# LLM Answer:
# The main move of the Ruy Lopez opening is \"1. e4.\" The purpose of this move is to
# LLM Answer:
# Answer: a. The purpose of the main move of the Ruy Lopez opening is to control the center with the bishop.
#
# Explan
# correct
# Progress: 0.36666666666666664
# Accuracy: 0.8181818181818182
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the first move of the black pieces in the Caro-Khan opening ?
# a)The purpose of the first black move of the Caro-Khan is :
#  to control the center with the pawn on c6.
# b)The purpose of the first black move of the Caro-Khan is :
#  to develop the knight to f6.
# c)The idea of the Caro-Khan opening is to make the bishop in b7
# d)The threat of the Caro-Khan opening is to attack the pawns on e4 and d4.
# first think step by step
#
# LLM Answer:
# The first move of the Caro-Khan opening is \"1
# LLM Answer:
# Answer: a. The purpose of the first black move of the Caro-Khan is to
# correct
# Progress: 0.4
# Accuracy: 0.8333333333333334
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main idea of the third move often played by white in the Queen's Gambit?
# a)The main idea of the third move often played by white in the Queen's Gambit is :
#  to develop the knight to a more central square.
# b)The main idea of the third move often played by white in the Queen's Gambit is :
#  to castle the king.
# c)The Queen's Gambit is characterized by the moves :
#  1. d4 d5  ..
# d)The purpose of the third move for white is often to control the center.
# first think step by step
#
# LLM Answer:
# The main idea of the third move often played by white in
# LLM Answer:
# Answer: d. The purpose of the third move for white is often to control the center
# wrong
# Progress: 0.43333333333333335
# Accuracy: 0.7692307692307693
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the benefit of controlling the center with d7-d5 in the Sicilian defense?
# a)The benefit of controlling the center with d7-d5 in the Sicilian defense is :
#  to prevent white from controlling the center.
# b)The benefit of controlling the center with d7-d5 in the Sicilian defense is :
#  to prepare for the move ...e7-e5.
# c)The main line of the Sicilian  is :
#  1. e4 c5 ..
# d)The characteristic move of the Sicilian defense is :
#  e7-e5 ..
# first think step by step
#
# LLM Answer:
# The main line of the Sicilian defense is
# LLM Answer:
# Answer: a
#
# Explanation: The Sicilian Defense aims to
# correct
# Progress: 0.4666666666666667
# Accuracy: 0.7857142857142857
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the knight move in the French defense ?
# a)The purpose of the knight move in the French defense is :
#  to attack the square f3.
# b)The purpose of the knight move in the French defense is :
#  to develop the knight to a more central square.
# c)The French defense is characterized by the move :
#  1. e4 e6
# d)The threat of the French defense is to pin the knight on f3.
# first think step by step
#
# LLM Answer:
# The French defense is characterized by the move : 1. e4 e6.\"
#
# The purpose of the knight move in the French defense is :
# b) to develop the
# LLM Answer:
# Answer: d. The French defense is known for \"its ability to pin the knight on f3, threatening to take it.\" The purpose of the knight move in the French defense is not explicitly to attack the
# wrong
# Progress: 0.5
# Accuracy: 0.7333333333333333
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the main characteristic move in the King's Indian defense?
# a)The purpose of the main characteristic move  of the King's Indian defense is :
#  to prepare for the move ...e7-e5.
# b)The purpose of the main characteristic move of the King's Indian defense is :
#  to develop the knight to a more central square.
# c)The characteristic move in the King's Indian typically starts the development of the pieces on the kingside
# d)The purpose of the King's Indian defense is often to put pressure on the center.
# first think step by step
#
# LLM Answer:
# The main characteristic move of the King's Indian defense is \"the move...f7-f
# LLM Answer:
# Answer: a
#
# Explanation: The main characteristic move of the King's Indian defense is \"the move...f
# wrong
# Progress: 0.5333333333333333
# Accuracy: 0.6875
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is one of the main ideas in Alekhine's Defense?
# a)One of the main ideas in Alekhine's Defense is :
#  to fianchetto the dark bishop to g7.
# b)Alekhine's Defense is often considered :
#  a classical opening..
# c)The first move of Alekhine's Defense is :
#  1. e4 Nf6
# d)The purpose of the Alekhine's Defense is often to put pressure on the center.
# first think step by step
#
# LLM Answer:
# The main idea in Alekhine's Defense is to fianchetto the dark bishop to g7. Answer: a.
#
# Explanation
# correct
# Progress: 0.5666666666666667
# Accuracy: 0.7058823529411765
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main threat of the Pirc Defense?
# a)The main threat of the Pirc Defense is :
#  to blockade the center and slow down white's development.
# b)The main threat of the Pirc Defense is :
#  to control the center with e7-e5.
# c)The main line of the Pirc Defense is :
#  1. e4 d6 ..
# d)The Pirc Defense is considered a :
#  hypermodern opening.
# first think step by step
#
# LLM Answer:
# The main threat of the Pirc Defense is :
#  to blockade the center and slow down white's development.
#
# Answer: a.
#
# Explanation:
# The Pir
# correct
# Progress: 0.6
# Accuracy: 0.7222222222222222
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the typical strategy in the Scandinavian Defense?
# a)The typical strategy in the Scandinavian Defense is :
#  to attack the center pawns with the queen..
# b)The Scandinavian Defense is considered :
#  a classical opening..
# c)The main line of the Scandinavian Defense is :
#  1.e4 d5 ..
# d)The threat of the Scandinavian Defense is to slow down white's development and control the center with d5.
# first think step by step
#
# LLM Answer:
# The typical strategy in the Scandinavian Defense is :
# to challenge white's control of the center with an early move...d5
# LLM Answer:
# Answer: d. The threat of the Scandinavian Defense is to slow down white's development and control the center with d5.
# wrong
# Progress: 0.6333333333333333
# Accuracy: 0.6842105263157895
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the benefit of fianchettoing the kingside bishop to g2 in the English Opening?
# a)The benefit of fianchettoing the kingside bishop to g2 in the English Opening is :
#  to control the long diagonal and help protect the king.
# b)The main characteristic of the English Opening is :
#  to fianchetto  the queenside  to b2
# c)The main line of the English Opening is :
#  1. c4 ..
# d)The English Opening is considered a :
#  hypermodern opening.
# first think step by step
#
# LLM Answer:
# The main characteristic of the English Opening is :
#  to fianchet
# LLM Answer:
# Answer: a
#
# Explanation: Fianchettoing the kingside bishop to g2
# correct
# Progress: 0.6666666666666666
# Accuracy: 0.7
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main threat of the Ruy Lopez opening?
# a)The main threat of the Ruy Lopez opening is :
#  a strong control of the center.
# b)The main threat of the Ruy Lopez opening is :
#  a strong attack on the king.
# c)The main idea of the Ruy Lopez  is :
#  1. e4  ..
# d)The purpose of the main move for white is often to control the center.
# first think step by step
#
# LLM Answer:
# The main idea of the Ruy Lopez opening is : 1. e4. The main threat of the Ruy Lopez opening is : a strong control of the center.
#
# LLM Answer:
# Answer: d. The main idea of the Ruy Lopez opening is to control the center with the move 1. e4. This move allows white to gain space and initiate attacks against black's position.
# wrong
# Progress: 0.7
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main purpose of the first move of the black pieces in the Caro-Khan opening ?
# a)The main purpose of the first black move of the Caro-Khan is :
#  to control the center with the pawn on c6.
# b)The main purpose of the first black move of the Caro-Khan is :
#  to develop the knight to f6.
# c)The idea of the Caro-Khan opening is to make the bishop in b7
# d)The threat of the Caro-Khan opening is to attack the pawns on e4 and d4.
# first think step by step
#
# LLM Answer:
# The main purpose of the first move of the black pieces
# LLM Answer:
# Answer: a. The main purpose of the first black move of the Caro-
# correct
# Progress: 0.7333333333333333
# Accuracy: 0.6818181818181818
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main idea of the third move often played by white in the Queen's Gambit?
# a)The main idea of the third move often played by white in the Queen's Gambit is :
#  to develop the knight to a more central square.
# b)The main idea of the third move often played by white in the Queen's Gambit is :
#  to castle the king.
# c)The Queen's Gambit is characterized by the moves :
#  1. d4 d5  ..
# d)The purpose of the third move for white is often to control the center.
# first think step by step
#
# LLM Answer:
# The main idea of the third move often played by white in
# LLM Answer:
# Answer: d. The purpose of the third move for white is often to control the center
# wrong
# Progress: 0.7666666666666667
# Accuracy: 0.6521739130434783
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the benefit of controlling the center with d7-d5 in the Sicilian defense?
# a)The benefit of controlling the center with d7-d5 in the Sicilian defense is :
#  to prevent white from controlling the center.
# b)The benefit of controlling the center with d7-d5 in the Sicilian defense is :
#  to prepare for the move ...e7-e5.
# c)The main line of the Sicilian  is :
#  1. e4 c5 ..
# d)The characteristic move of the Sicilian defense is :
#  e7-e5 ..
# first think step by step
#
# LLM Answer:
# The main line of the Sicilian defense is
# LLM Answer:
# Answer: a
#
# Explanation: The Sicilian Defense aims to
# correct
# Progress: 0.8
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the knight move in the French defense ?
# a)The purpose of the knight move in the French defense is :
#  to attack the square f3.
# b)The purpose of the knight move in the French defense is :
#  to develop the knight to a more central square.
# c)The French defense is characterized by the move :
#  1. e4 e6
# d)The threat of the French defense is to pin the knight on f3.
# first think step by step
#
# LLM Answer:
# The French defense is characterized by the move : 1. e4 e6.\"
#
# The purpose of the knight move in the French defense is :
# b) to develop the
# LLM Answer:
# Answer: d. The French defense is known for \"its ability to pin the knight on f3, threatening to take it.\" The purpose of the knight move in the French defense is not explicitly to attack the
# wrong
# Progress: 0.8333333333333334
# Accuracy: 0.64
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the main characteristic move in the King's Indian defense?
# a)The purpose of the main characteristic move  of the King's Indian defense is :
#  to prepare for the move ...e7-e5.
# b)The purpose of the main characteristic move of the King's Indian defense is :
#  to develop the knight to a more central square.
# c)The characteristic move in the King's Indian typically starts the development of the pieces on the kingside
# d)The purpose of the King's Indian defense is often to put pressure on the center.
# first think step by step
#
# LLM Answer:
# The main characteristic move of the King's Indian defense is \"the move...f7-f
# LLM Answer:
# Answer: a
#
# Explanation: The main characteristic move of the King's Indian defense is \"the move...f
# wrong
# Progress: 0.8666666666666667
# Accuracy: 0.6153846153846154
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is one of the main ideas in Alekhine's Defense?
# a)One of the main ideas in Alekhine's Defense is :
#  to fianchetto the dark bishop to g7.
# b)Alekhine's Defense is often considered :
#  a classical opening..
# c)The first move of Alekhine's Defense is :
#  1. e4 Nf6
# d)The purpose of the Alekhine's Defense is often to put pressure on the center.
# first think step by step
#
# LLM Answer:
# The main idea in Alekhine's Defense is to fianchetto the dark bishop to g7. Answer: a.
#
# Explanation
# correct
# Progress: 0.9
# Accuracy: 0.6296296296296297
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main threat of the Pirc Defense?
# a)The main threat of the Pirc Defense is :
#  to blockade the center and slow down white's development.
# b)The main threat of the Pirc Defense is :
#  to control the center with e7-e5.
# c)The main line of the Pirc Defense is :
#  1. e4 d6 ..
# d)The Pirc Defense is considered a :
#  hypermodern opening.
# first think step by step
#
# LLM Answer:
# The main threat of the Pirc Defense is :
#  to blockade the center and slow down white's development.
#
# Answer: a.
#
# Explanation:
# The Pir
# correct
# Progress: 0.9333333333333333
# Accuracy: 0.6428571428571429
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the typical strategy in the Scandinavian Defense?
# a)The typical strategy in the Scandinavian Defense is :
#  to attack the center pawns with the queen..
# b)The Scandinavian Defense is considered :
#  a classical opening..
# c)The main line of the Scandinavian Defense is :
#  1.e4 d5 ..
# d)The threat of the Scandinavian Defense is to slow down white's development and control the center with d5.
# first think step by step
#
# LLM Answer:
# The typical strategy in the Scandinavian Defense is :
# to challenge white's control of the center with an early move...d5
# LLM Answer:
# Answer: d. The threat of the Scandinavian Defense is to slow down white's development and control the center with d5.
# wrong
# Progress: 0.9666666666666667
# Accuracy: 0.6206896551724138
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the benefit of fianchettoing the kingside bishop to g2 in the English Opening?
# a)The benefit of fianchettoing the kingside bishop to g2 in the English Opening is :
#  to control the long diagonal and help protect the king.
# b)The main characteristic of the English Opening is :
#  to fianchetto  the queenside  to b2
# c)The main line of the English Opening is :
#  1. c4 ..
# d)The English Opening is considered a :
#  hypermodern opening.
# first think step by step
#
# LLM Answer:
# The main characteristic of the English Opening is :
#  to fianchet
# LLM Answer:
# Answer: a
#
# Explanation: Fianchettoing the kingside bishop to g2
# correct
# Progress: 1.0
# Accuracy: 0.6333333333333333

# %% [markdown]
# --------------------------

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# %%capture
# !git clone 'https://github.com/ggerganov/llama.cpp.git'

# %%
# !cd llama.cpp
# !pip install -r llama.cpp/requirements.txt
# Out:
# Collecting numpy~=1.24.4 (from -r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 1))
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 50.2 MB/s eta 0:00:00
# Collecting sentencepiece~=0.2.0 (from -r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 2))
#   Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.0 MB/s eta 0:00:00
# Collecting transformers<5.0.0,>=4.40.1 (from -r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3))
#   Downloading transformers-4.41.2-py3-none-any.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 64.0 MB/s eta 0:00:00
# Collecting gguf>=0.1.0 (from -r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 4))
#   Downloading gguf-0.6.0-py3-none-any.whl (23 kB)
# Collecting protobuf<5.0.0,>=4.21.0 (from -r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 5))
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 30.8 MB/s eta 0:00:00
# Collecting torch~=2.1.1 (from -r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2))
#   Downloading torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (0.23.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (2.31.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3))
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 84.9 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (4.66.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.0.106)
# Collecting nvidia-nccl-cu12==2.18.1 (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2))
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.1.105)
# Collecting triton==2.1.0 (from torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2))
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.40.1->-r llama.cpp/./requirements/requirements-convert-legacy-llama.txt (line 3)) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch~=2.1.1->-r llama.cpp/./requirements/requirements-convert-hf-to-gguf.txt (line 2)) (1.3.0)
# Installing collected packages: sentencepiece, triton, protobuf, nvidia-nccl-cu12, numpy, gguf, torch, tokenizers, transformers
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.1.99
#     Uninstalling sentencepiece-0.1.99:
#       Successfully uninstalled sentencepiece-0.1.99
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.0
#     Uninstalling triton-2.3.0:
#       Successfully uninstalled triton-2.3.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.20.5
#     Uninstalling nvidia-nccl-cu12-2.20.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.20.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.36.2
#     Uninstalling transformers-4.36.2:
#       Successfully uninstalled transformers-4.36.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.3 which is incompatible.
# torchaudio 2.3.0+cu121 requires torch==2.3.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 2.1.2 which is incompatible.
# torchvision 0.18.0+cu121 requires torch==2.3.0, but you have torch 2.1.2 which is incompatible.
# Successfully installed gguf-0.6.0 numpy-1.24.4 nvidia-nccl-cu12-2.18.1 protobuf-4.25.3 sentencepiece-0.2.0 tokenizers-0.19.1 torch-2.1.2 transformers-4.41.2 triton-2.1.0

# %%
from google.colab import drive
drive.mount('/content/drive')
